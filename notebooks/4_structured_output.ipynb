# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model = "openai/gpt-oss-120b")

# %%
text = "Hello, My name is Anuradha Joshi. My email id is anuradhaa.vits@gmail.com and i am 19 years old."

# %%
from pydantic import BaseModel, Field

class ResponseStructure(BaseModel):
    name : str = Field(description="The name of the person.")
    email : str = Field(description="The email of the person.")
    age : int = Field(description="The age of the person.")

structured_output = llm.with_structured_output(ResponseStructure)

# %%
res = structured_output.invoke(f"Please provide your name, email, and age from the following text: {text}")
res.model_dump()
# Out:
# {'name': 'Anuradha Joshi', 'email': 'anuradhaa.vits@gmail.com', 'age': 19}

# %%
class Movie(BaseModel):
    title: str  = Field (description = "Movie Title")
    year: int = Field (description = "Movie Released Year")

movie_structure = llm.with_structured_output(Movie)

res = movie_structure.invoke("Please provide the title and year of the movie '3 Idiots'.")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[19], line 7
#       3     year: int = Field (description = "Movie Released Year")
#       4
#       5 movie_structure = llm.with_structured_output(Movie)
#       6
# ----> 7 res = movie_structure.invoke("Please provide the title and year of the movie '3 Idiots'.")
#
# File ~\Documents\Gen AI\env\Lib\site-packages\langchain_core\runnables\base.py:3454, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3452 with set_config_context(config) as context:
#    3453     if i == 0:
# -> 3454         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3455     else:
#    3456         input_ = context.run(step.invoke, input_, config)
#
# File ~\Documents\Gen AI\env\Lib\site-packages\langchain_core\runnables\base.py:6014, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    6007 @override
# ...

# %%
res
# Out:
# Movie(title='Spiderman - BND', year=0)
