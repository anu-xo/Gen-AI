# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
llm = ChatGroq(model = "openai/gpt-oss-120b")
search = GoogleSerperAPIWrapper()

# %%
search.run ("which is the most famous ganesh temple in indore, madya pradesh, india?")
# Out:
# "Khajrana Ganesh Temple is a Hindu temple complex, situated in Khajrana area of Indore in the Indian state of Madhya Pradesh, India. The main temple in the ... Khajrana Ganesh Temple is one of the most revered religious sites in Indore, known for its peaceful and spiritual ambiance, enriched with cultural significance. Shri Bada Ganapati Temple @ Indore, Madhya Pradesh Better known for its size than antiquity, this temple houses very large murti of Ganesh ... This is an important place of Hindus. Khajrana Ganesha Temple was constructed by Rani Ahilyabai Holkar. This temple is one of the famous Hindu temples in India. Khajrana Ganesha Temple is a prominent landmark in Indore, boasting one of the city's largest temple complexes. It includes several small ... This is one of the most renowned Temples of Madhya Pradesh … is Lord Ganesha. This is one of the famous and largest Temple in Indore City. Timing: 6 AM to 10 PM Location :Khajrana Rd,Ganeshpuri Colony, Khajrana ,Indore,(M.P.) Khajrana Ganesha Temple was constructed by Rani Ahilyabai Holkar. This temple ... 'Khajrana Temple', a temple of 'Lord Ganesha', the most visited heritage spots of Indore. Ganesha Statue is more than 8 metres and has been recorded as the ... Khajrana Ganesh Mandir stands as one of the most revered spiritual landmarks in Indore, built by Maharani Ahilyabai Holkar in 1735. The temple was founded ..."

# %%
agent = create_agent(
    model = llm,
    tools = [search.run],
    system_prompt = "You are a helpful assistant that can search the web for information."
)

# %%
question = "which is the most famous ganesh temple in indore, madya pradesh, india?"

# %%
response = agent.invoke({"messages" : [{"role" : "user", "content" : "which is the most famous ganesh temple in indore, madya pradesh, india?"}]})
print(response["messages"][-1].content)
