# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model = "openai/gpt-oss-120b", streaming = True)

# %%
query = "How to detect a cyclic linked list in C++"

# %%
response = llm.stream(query)
for chunk in response:
    print(chunk.content, end = "")
# Out:
# Below is a complete, self‑contained guide to detecting a cycle (a “loop”) in a singly‑linked list in C++.
# It covers the classic **Floyd’s Tortoise‑and‑Hare** algorithm, an alternative using a hash table, and a few practical tips for production code.
#
# ---
#
# ## 1. Why a cycle matters
#
# A singly‑linked list is *acyclic* when every node’s `next` pointer eventually becomes `nullptr`.
# If a node points back to an earlier node, traversal never ends → infinite loop, memory leaks, crashes, etc. Detecting the cycle early lets you break it, report an error, or safely abort the traversal.
#
# ---
#
# ## 2. Floyd’s Tortoise‑and‑Hare (O(1) space)
#
# ### 2.1 Idea
#
# Two pointers walk through the list at different speeds:
#
# * **slow** moves one step per iteration.
# * **fast** moves two steps per iteration.
#
# If there is no cycle, `fast` will hit `nullptr`.
# If there is a cycle, `fast` will eventually “lap” `slow` and the two pointers become equal.
#
# ### 2.2 Detect‑only version
#
# ...
